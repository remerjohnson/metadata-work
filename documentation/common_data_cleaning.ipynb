# %% [markdown]
# # Common Data Cleaning and Structuring Tasks
#
# This notebook will be a space to test out some common data cleaning tasks. The goal is to turn these into functions and scripts that could also then be fed to a GUI like (for example [Gooey](https://github.com/chriskiehl/Gooey)).

# %% [markdown]
# ## Double Spaces
# Consecutive spaces is something that is super difficult to detect visually, but that in all cases, we want to get rid of. So it will make a good first test for our data cleaning tasks.
# We will need to use regular expressions, so let's first get some `import` statements going, for the regex module `re`. We will also be using DataFrames heavily, so we will import `pandas` for good measure

# %%
import re
import pandas as pd

# %% [markdown]
# We need to have `pandas` read the test (csv) file that we _know_ has double spaces, which is in our `/test` directory: `double_spaces.csv`. This will create our DataFrame:

# %%
data_file = pd.read_csv("../test/double_spaces.csv")

# %% [markdown]
# Now that we have our DataFrame (called `data_file`), we can call the `pandas` function `.head()` to inspect the first 5 rows:

# %%
data_file.head()
# Out:
#    Object Unique ID      Level                                     File name  \
# 0                 1     Object                                           NaN
# 1                 1  Component              IdeasStFrancis_2017_12_06_HQ.mp4
# 2                 1  Component  IDEAS_St_Francis_de_los_Barrios_01_of_88.jpg
# 3                 1  Component  IDEAS_St_Francis_de_los_Barrios_02_of_88.jpg
# 4                 1  Component  IDEAS_St_Francis_de_los_Barrios_03_of_88.jpg
#
#        File use            Type of Resource         Language  \
# 0           NaN  moving image | still image  eng  - English
# 1  video-source                         NaN              NaN
# 2  image-source                         NaN              NaN
# 3  image-source                         NaN              NaN
# 4  image-source                         NaN              NaN
#
#                            Title Person:Creator Person:Choreographer  \
# 0  St. Francis  de los  Barrios             NaN                  NaN
# 1                        Program            NaN                  NaN
# 2                        Image 1            NaN                  NaN
# 3                        Image 2            NaN                  NaN
# 4                        Image 3            NaN                  NaN
#
#   Person:Composer  ...    End date  \
# 0  Waters, Joseph  ...  2017-12-06
# 1             NaN  ...         NaN
# 2             NaN  ...         NaN
# 3             NaN  ...         NaN
# 4             NaN  ...         NaN
#
#                                     Note:description  \
# 0  An indie-class, trans-genre rock opera based o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Subject:topic                   Subject:personal name  \
# 0  Opera | Transgender sex workers  Saint Francis of Assisi | Pope Francis
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                     NaN
#
#                                   Subject:geographic  \
# 0  Tijuana (Baja California, Mexico) | Zona Norte...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             Related resource:related Access granted  \
# 0  IDEAS Performance Photographs via Flickr @ htt...            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Copyright status Copyright holder CC license
# 0              NaN              NaN        NaN
# 1              NaN              NaN        NaN
# 2              NaN              NaN        NaN
# 3              NaN              NaN        NaN
# 4              NaN              NaN        NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# Now we can use `pd.replace()` (which is a `pandas` specific function that is similar to the regular expression module `re.sub` function).
# We want to replace the pattern of two consecutive spaces with one space:

# %%
data_file.replace('\s\s', ' ', regex=True, inplace=True)

# %% [markdown]
# Let's define this in a function so we can reuse it if we want in the future:

# %%
def remove_double_spaces(data_input):
    """
    Take the DataFrame and remove consecutive spaces
    """
    data_input = data_input.replace(to_replace='\s\s', value=' ', regex=True, inplace=True)
    return data_input

# %%
remove_double_spaces(data_file)

# %%
data_file.head()
# Out:
#    Object Unique ID      Level                                     File name  \
# 0                 1     Object                                           NaN
# 1                 1  Component              IdeasStFrancis_2017_12_06_HQ.mp4
# 2                 1  Component  IDEAS_St_Francis_de_los_Barrios_01_of_88.jpg
# 3                 1  Component  IDEAS_St_Francis_de_los_Barrios_02_of_88.jpg
# 4                 1  Component  IDEAS_St_Francis_de_los_Barrios_03_of_88.jpg
#
#        File use            Type of Resource        Language  \
# 0           NaN  moving image | still image  eng - English
# 1  video-source                         NaN             NaN
# 2  image-source                         NaN             NaN
# 3  image-source                         NaN             NaN
# 4  image-source                         NaN             NaN
#
#                          Title Person:Creator Person:Choreographer  \
# 0  St. Francis de los Barrios             NaN                  NaN
# 1                      Program            NaN                  NaN
# 2                      Image 1            NaN                  NaN
# 3                      Image 2            NaN                  NaN
# 4                      Image 3            NaN                  NaN
#
#   Person:Composer  ...    End date  \
# 0  Waters, Joseph  ...  2017-12-06
# 1             NaN  ...         NaN
# 2             NaN  ...         NaN
# 3             NaN  ...         NaN
# 4             NaN  ...         NaN
#
#                                     Note:description  \
# 0  An indie-class, trans-genre rock opera based o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Subject:topic                   Subject:personal name  \
# 0  Opera | Transgender sex workers  Saint Francis of Assisi | Pope Francis
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                     NaN
#
#                                   Subject:geographic  \
# 0  Tijuana (Baja California, Mexico) | Zona Norte...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             Related resource:related Access granted  \
# 0  IDEAS Performance Photographs via Flickr @ htt...            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Copyright status Copyright holder CC license
# 0              NaN              NaN        NaN
# 1              NaN              NaN        NaN
# 2              NaN              NaN        NaN
# 3              NaN              NaN        NaN
# 4              NaN              NaN        NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# Upon inspection of the result, we see the spaces are now all singles. And since we made a function, we can add it in our overall program, as well as other things, like write up a test to make sure the function is actually doing what we think it should be doing.

# %% [markdown]
# ## Trimming whitespace
#
# Similar to double spacing, cell values with leading or trailing whitespaces are a pain, and again, very hard to detect visually. We know that python has the built-in `trim()` function, but `pandas` also has an exact same function to use for DataFrames: `.strip()`.
#
# Where this gets tricky is that for DataFrames, `.apply()` is more specific, whereas we need `.applymap()` in order to apply it to the _entire_ DataFrame. We must also take into account that not every data type in our DataFrame might be strings, so we will use a conditional to _only_ apply it to strings, otherwise we will raise errors:

# %%
data_file2 = pd.read_csv("../test/untrimmed_spaces.csv")

# %%
def trim_spaces(data_frame):
    """
    Take the DataFrame and remove surrounding spaces of values
    """
    trim_strings = lambda x: x.strip() if type(x) is str else x
    return data_frame.applymap(trim_strings)

# %%
result2 = trim_spaces(data_file2)

# %%
result2.head()
# Out:
#    Object Unique ID      Level                                     File name  \
# 0                 1     Object                                           NaN
# 1                 1  Component              IdeasStFrancis_2017_12_06_HQ.mp4
# 2                 1  Component  IDEAS_St_Francis_de_los_Barrios_01_of_88.jpg
# 3                 1  Component  IDEAS_St_Francis_de_los_Barrios_02_of_88.jpg
# 4                 1  Component  IDEAS_St_Francis_de_los_Barrios_03_of_88.jpg
#
#        File use            Type of Resource        Language  \
# 0           NaN  moving image | still image  eng  - English
# 1  video-source                         NaN             NaN
# 2  image-source                         NaN             NaN
# 3  image-source                         NaN             NaN
# 4  image-source                         NaN             NaN
#
#                         Title Person:Creator Person:Choreographer  \
# 0  St. Francis de los Barrios            NaN                  NaN
# 1                     Program            NaN                  NaN
# 2                     Image 1            NaN                  NaN
# 3                     Image 2            NaN                  NaN
# 4                     Image 3            NaN                  NaN
#
#   Person:Composer  ...    End date  \
# 0  Waters, Joseph  ...  2017-12-06
# 1             NaN  ...         NaN
# 2             NaN  ...         NaN
# 3             NaN  ...         NaN
# 4             NaN  ...         NaN
#
#                                     Note:description  \
# 0  An indie-class, trans-genre rock opera based o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Subject:topic                   Subject:personal name  \
# 0  Opera | Transgender sex workers  Saint Francis of Assisi | Pope Francis
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                     NaN
#
#                                   Subject:geographic  \
# 0  Tijuana (Baja California, Mexico) | Zona Norte...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             Related resource:related Access granted  \
# 0  IDEAS Performance Photographs via Flickr @ htt...            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Copyright status Copyright holder CC license
# 0              NaN              NaN        NaN
# 1              NaN              NaN        NaN
# 2              NaN              NaN        NaN
# 3              NaN              NaN        NaN
# 4              NaN              NaN        NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# That's another function for our program done!

# %% [markdown]
# ### Stripping strings based on a character
# A use case we have is that in the report we get exported, entities are placed in a cell with both its value and then an '@ bdxxxxx' ARK number. We don't want the ARK values in the cell, so we'll try to slice those out. Let's try this using just base (built-in) Python functions first

# %%
string = "tha - Thai @ bd21038465"
stripped = string.rsplit('@')
print(stripped[0].strip())
# Out:
# tha - Thai

# %%
string = ["tha - Thai @ bd21038465", "tgl - Tagalog @ bd07385470", "tam - Tamil @ bd11482017", "syr - Syriac @ bd2445142b"]
for s in string:
    s = s.rsplit('@')
    print(s[0].strip())
# Out:
# tha - Thai
# tgl - Tagalog
# tam - Tamil
# syr - Syriac

# %% [markdown]
# Now, let's try to do that in `pandas`

# %%
df = pd.DataFrame({'Language': ['tha - Thai @ bd21038465', 
                                'tgl - Tagalog @ bd07385470', 
                                'tam - Tamil @ bd11482017', 
                                'syr - Syriac @ bd2445142b']})
df
# Out:
#                      Language
# 0     tha - Thai @ bd21038465
# 1  tgl - Tagalog @ bd07385470
# 2    tam - Tamil @ bd11482017
# 3   syr - Syriac @ bd2445142b

# %%
df['Language'] = df.Language.str.split('@', expand=True)

# %%
df
# Out:
#          Language
# 0     tha - Thai
# 1  tgl - Tagalog
# 2    tam - Tamil
# 3   syr - Syriac

# %% [markdown]
# ### Dates
# Ah, the true bane of our existence: dates. We will attempt to do some dates parsing. Also, if we can, we should take clean dates and try to populate the "Begin Date" and "End Date" columns

# %%
df_dates = pd.read_excel("../test/catalhoyuk_glimpse_v2_delimiters.xlsx")

# %%
columns = df_dates.columns
print(columns)
# Out:
# Index(['Object Unique ID', 'Level', 'File name', 'File use',
#        'Type of Resource', 'Language', 'Title',
#        'Person:Principal investigator', 'Person:Author',
#        'Person:Research team member', 'Corporate:Contributor', 'Date:creation',
#        'Begin date', 'End date', 'Note:description', 'Note:technical details',
#        'Note:scope and content', 'Note:preferred citation',
#        'Note:related publications', 'Subject:topic', 'Geographic:point',
#        'Related resource:related', 'Related resource:related.1'],
#       dtype='object')

# %%
for column in columns:
    if column.lower().startswith("date"):
        print(column)
# Out:
# Date:creation

# %%
date_begin = []
date_end = []

for column in columns:
    if column.lower().startswith("date"):
        for row in df_dates[column]:
            if len(str(row)) == 4:
                date_begin.append(str(row) + "-01-01")
                date_end.append(str(row) + "-12-31")
            else:
                date_begin.append("")
                date_end.append("")

# %%
df_dates['Begin date'] = date_begin
df_dates['End date'] = date_end

# %%
df_dates.head()
# Out:
#    Object Unique ID      Level                        File name      File use  \
# 0               1.0     Object                              NaN           NaN
# 1               1.0  Component  S.10_Sequence_Levels_Render.PNG  image-source
# 2               1.0  Component      S.10_Sequence_App_Win64.zip  data-service
# 3               1.0  Component    S.10_Sequence_App_Project.zip  data-service
# 4               2.0     Object                              NaN           NaN
#
#                                     Type of Resource  \
# 0                      data | still image | software
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  data | still image | software | three dimensio...
#
#                                       Language  \
# 0  zxx - No linguistic content; Not applicable
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                eng - English
#
#                                                Title  \
# 0  Çatalhöyük, South Area, 'Shrine' 10 Virtual Re...
# 1  3-D render of all superimposed buildings in th...
# 2  Unity 3D app including Win64 Executable and al...
# 3                        Unity 3D app project folder
# 4            Çatalhöyük, South Area, Building 17.2.2
#
#   Person:Principal investigator                    Person:Author  \
# 0               Lercari, Nicola                              NaN
# 1                           NaN                  Lercari, Nicola
# 2                           NaN  Aboulhosn, Jad; Lercari, Nicola
# 3                           NaN  Aboulhosn, Jad; Lercari, Nicola
# 4               Lercari, Nicola                              NaN
#
#                          Person:Research team member  ...    End date  \
# 0  Cox, Grant; Busacca, Gesualdo; Campiani, Arian...  ...  2018-12-31
# 1                                                NaN  ...  2018-12-31
# 2                                                NaN  ...  2019-12-31
# 3                                                NaN  ...  2019-12-31
# 4  Cox, Grant; Busacca, Gesualdo; Campiani, Arian...  ...  2018-12-31
#
#                                     Note:description  \
# 0  3-D reconstruction of the entire Çatalhöyük 'S...
# 1  3-D render displaying 'Shrine' 10 Sequence lev...
# 2  This archive includes a fully functional demo ...
# 3  This file includes all assets needed to recrea...
# 4  3-D reconstruction of Çatalhöyük, South Area, ...
#
#                               Note:technical details  \
# 0                                                NaN
# 1  Snapshot captured in Unity 3D. File format is PNG
# 2  This app was created in Unity 3D version 2018....
# 3  This Unity project was created in Unity 2018.2...
# 4                                                NaN
#
#                               Note:scope and content  \
# 0  Updates to the preceding (2018) version: Win 1...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Updates to the preceding (2018) version: metad...
#
#                              Note:preferred citation  \
# 0  Lercari, Nicola; Cox, Grant; Busacca, Gesualdo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Lercari, Nicola; Cox, Grant; Busacca, Gesualdo...
#
#                            Note:related publications  \
# 0  Hodder, I. 2007. Çatalhöyük in the Context of ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Farid, S. 2007a. Level IX Relative Heights, Bu...
#
#                               Subject:topic     Geographic:point  \
# 0  Neolithic settlement, Neolithic building  37.672122,32.823508
# 1                                       NaN                  NaN
# 2                                       NaN                  NaN
# 3                                       NaN                  NaN
# 4  Neolithic settlement, Neolithic building  37.672122,32.823508
#
#                             Related resource:related  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Unity User Manual @ https://docs.unity3d.com/M...
# 4  Building 17 excavation data provided by Çatalh...
#
#                           Related resource:related.1
# 0  2018 version (pre-peer review) of this item @ ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  2018 version (pre-peer review) of this item @ ...
#
# [5 rows x 23 columns]
