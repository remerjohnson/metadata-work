# %% [markdown]
# # Structuring a complex object OLR with Python
# For simple objects, OLRs are pretty simple, since you can easily do `ls > filelist.txt` to get a file listing in a directory, and paste that into your OLR. But what about complex objects? Additionally, what if it's a mix of simple and complex objects?
#
# That's where `pyobstruct.py` comes in. It takes user input for the absolute path of the files on staging, parses that into a data frame, then outputs it as a csv.
#
# Although it "works" now, `pyobstruct` could use improvement. It sorts in a weird way, so that e.g. `b100291089_2.tif` comes a line before `b100291089_1.tif`. It also does not print the single "object" row that contains object-level information. This notebook will tinker and try to achieve these things.

# %%
import pandas as pd
import sys
import os
import numpy as np

# %% [markdown]
# Let's isolate the first part of the script, which seems to be pretty solid. It takes the absolute path of the files, and returns some useful information, like how many objects there are

# %%
user_path = input("Enter the absolute path of the directory containing all objects: ")
os.chdir(user_path)
folders = [name for name in os.listdir(".") if os.path.isdir(name)]

# Make a list of the files within the folders
files = []
for f in folders:
    file = os.listdir(f)
    files.append(file)
    continue

# Remove any Thumbs.db files in our list
for file in files:
    while 'Thumbs.db' in file: file.remove('Thumbs.db')    
    
# Give the user some textual output of the files, then report total number of objects
print("Here is a sample of the files:")
print('\n',files[0:15])
print('\n')
print("There are",len(files),"total objects")
# Out:
# Enter the absolute path of the directory containing all objects:  /mnt/digital-staging/Mexican-Broadsides/batch3/Working_Files
# Here is a sample of the files:
#
#  [['b100291089_2.tif', 'b100291089_1.tif'], ['b10343608x_1.tif'], ['b9675820x_1.tif'], ['b103565759_1.tif', 'b103565759_2.tif'], ['b103720285_1.tif'], ['b103436133_1.tif'], ['b100710001_1.tif'], ['b103785012_1.tif', 'b103785012_2.tif'], ['b10065731x_1.tif'], ['b103784457_1.tif', 'b103784457_2.tif'], ['b103719593_1.tif'], ['b100311556_1.tif'], ['b103836895_2.tif', 'b103836895_1.tif'], ['b100753668_1.tif'], ['b103722154_2.tif', 'b103722154_1.tif']]
#
#
# There are 111 total objects

# %% [markdown]
# As you can see, the second tif `_2` comes before the first, `_1`. Perhaps we can sort this by using `sort()` on the list

# %%
user_path = input("Enter the absolute path of the directory containing all objects: ")
os.chdir(user_path)
folders = [name for name in os.listdir(".") if os.path.isdir(name)]

# Make a list of the files within the folders
files = []
for f in folders:
    file = sorted(os.listdir(f))
    files.append(file)
    continue

# Remove any Thumbs.db files in our list
for file in files:
    while 'Thumbs.db' in file: file.remove('Thumbs.db') 
    sorted(file)
    

# Give the user some textual output of the files, then report total number of objects
print("Here is a sample of the files:")
print('\n',files[0:15])
print('\n')
print("There are",len(files),"total objects")
# Out:
# Enter the absolute path of the directory containing all objects:  /mnt/digital-staging/Mexican-Broadsides/batch3/Working_Files
# Here is a sample of the files:
#
#  [['b100291089_1.tif', 'b100291089_2.tif'], ['b10343608x_1.tif'], ['b9675820x_1.tif'], ['b103565759_1.tif', 'b103565759_2.tif'], ['b103720285_1.tif'], ['b103436133_1.tif'], ['b100710001_1.tif'], ['b103785012_1.tif', 'b103785012_2.tif'], ['b10065731x_1.tif'], ['b103784457_1.tif', 'b103784457_2.tif'], ['b103719593_1.tif'], ['b100311556_1.tif'], ['b103836895_1.tif', 'b103836895_2.tif'], ['b100753668_1.tif'], ['b103722154_1.tif', 'b103722154_2.tif']]
#
#
# There are 111 total objects

# %% [markdown]
# Nice, now the files should appear in order

# %%
user_path = input("Enter the absolute path of the directory containing all objects: ")
os.chdir(user_path)
folders = [name for name in os.listdir(".") if os.path.isdir(name)]

# Make a list of the files within the folders
files = []
for f in folders:
    file = sorted(os.listdir(f))
    files.append(file)
    continue

# Remove any Thumbs.db files in our list
for file in files:
    while 'Thumbs.db' in file: file.remove('Thumbs.db')    
    
# Give the user some textual output of the files, then report total number of objects
print("Here is a sample of the files:")
print('\n',files[0:15])
print('\n')
print("There are",len(files),"total objects")

# Make a dictionary where the key is the bib/folder, and the value is one or more files
listing_dict = dict(zip(folders, files))

# Make a dictionary of a dataFrame using the above dictionary 
#dict_of_df = {k: pd.DataFrame(v) for k,v in listing_dict.items()}

# Make THAT a dataFrame
#df = pd.concat(dict_of_df, names=['bib','filename'])

df = pd.DataFrame.from_dict(listing_dict, orient='index', columns=['file_1', 'file_2'])

# Give the user a sample of the dataFrame
print(df[0:50])
# Out:
# Enter the absolute path of the directory containing all objects:  /mnt/digital-staging/Mexican-Broadsides/batch3/Working_Files
# Here is a sample of the files:
#
#  [['b100291089_1.tif', 'b100291089_2.tif'], ['b10343608x_1.tif'], ['b9675820x_1.tif'], ['b103565759_1.tif', 'b103565759_2.tif'], ['b103720285_1.tif'], ['b103436133_1.tif'], ['b100710001_1.tif'], ['b103785012_1.tif', 'b103785012_2.tif'], ['b10065731x_1.tif'], ['b103784457_1.tif', 'b103784457_2.tif'], ['b103719593_1.tif'], ['b100311556_1.tif'], ['b103836895_1.tif', 'b103836895_2.tif'], ['b100753668_1.tif'], ['b103722154_1.tif', 'b103722154_2.tif']]
#
#
# There are 111 total objects
#                       file_1            file_2
# b100291089  b100291089_1.tif  b100291089_2.tif
# b10343608x  b10343608x_1.tif              None
# b9675820x    b9675820x_1.tif              None
# b103565759  b103565759_1.tif  b103565759_2.tif
# b103720285  b103720285_1.tif              None
# b103436133  b103436133_1.tif              None
# b100710001  b100710001_1.tif              None
# b103785012  b103785012_1.tif  b103785012_2.tif
# b10065731x  b10065731x_1.tif              None
# b103784457  b103784457_1.tif  b103784457_2.tif
# b103719593  b103719593_1.tif              None
# b100311556  b100311556_1.tif              None
# b103836895  b103836895_1.tif  b103836895_2.tif
# b100753668  b100753668_1.tif              None
# b103722154  b103722154_1.tif  b103722154_2.tif
# b103719829  b103719829_1.tif              None
# b103503584  b103503584_1.tif              None
# b103831137  b103831137_1.tif              None
# b103618685  b103618685_1.tif  b103618685_2.tif
# b100489308  b100489308_1.tif              None
# b103786685  b103786685_1.tif              None
# b100756013  b100756013_1.tif              None
# b103506421  b103506421_1.tif  b103506421_2.tif
# b10079970x  b10079970x_1.tif              None
# b103926197  b103926197_1.tif              None
# b103785607  b103785607_1.tif              None
# b103584183  b103584183_1.tif              None
# b100756608  b100756608_1.tif              None
# b100800129  b100800129_1.tif              None
# b103706173  b103706173_1.tif              None
# b103831034  b103831034_1.tif  b103831034_2.tif
# b103786569  b103786569_1.tif              None
# b103691182  b103691182_1.tif              None
# b100800075  b100800075_1.tif              None
# b100751726  b100751726_1.tif  b100751726_2.tif
# b103720959  b103720959_1.tif              None
# b103618454  b103618454_1.tif  b103618454_2.tif
# b103720947  b103720947_1.tif              None
# b103618946  b103618946_1.tif              None
# b100756578  b100756578_1.tif              None
# b103609441  b103609441_1.tif  b103609441_2.tif
# b100659615  b100659615_1.tif  b100659615_2.tif
# b103705545  b103705545_1.tif  b103705545_2.tif
# b99338907    b99338907_1.tif              None
# b100294753  b100294753_1.tif  b100294753_2.tif
# b100713671  b100713671_1.tif  b100713671_2.tif
# b100757054  b100757054_1.tif  b100757054_2.tif
# b100531088  b100531088_1.tif  b100531088_2.tif
# b103786387  b103786387_1.tif  b103786387_2.tif
# b103722634  b103722634_1.tif  b103722634_2.tif

# %%
df2 = df.stack()
df2
# Out:
# b100291089  file_1    b100291089_1.tif
#             file_2    b100291089_2.tif
# b10343608x  file_1    b10343608x_1.tif
# b9675820x   file_1     b9675820x_1.tif
# b103565759  file_1    b103565759_1.tif
#             file_2    b103565759_2.tif
# b103720285  file_1    b103720285_1.tif
# b103436133  file_1    b103436133_1.tif
# b100710001  file_1    b100710001_1.tif
# b103785012  file_1    b103785012_1.tif
#             file_2    b103785012_2.tif
# b10065731x  file_1    b10065731x_1.tif
# b103784457  file_1    b103784457_1.tif
#             file_2    b103784457_2.tif
# b103719593  file_1    b103719593_1.tif
# b100311556  file_1    b100311556_1.tif
# b103836895  file_1    b103836895_1.tif
#             file_2    b103836895_2.tif
# b100753668  file_1    b100753668_1.tif
# b103722154  file_1    b103722154_1.tif
#             file_2    b103722154_2.tif
# b103719829  file_1    b103719829_1.tif
# b103503584  file_1    b103503584_1.tif
# b103831137  file_1    b103831137_1.tif
# b103618685  file_1    b103618685_1.tif
#             file_2    b103618685_2.tif
# b100489308  file_1    b100489308_1.tif
# b103786685  file_1    b103786685_1.tif
# b100756013  file_1    b100756013_1.tif
# b103506421  file_1    b103506421_1.tif
#                             ...
# b103722683  file_2    b103722683_2.tif
# b103618636  file_1    b103618636_1.tif
#             file_2    b103618636_2.tif
# b103584225  file_1    b103584225_1.tif
# b100752615  file_1    b100752615_1.tif
# b103585242  file_1    b103585242_1.tif
#             file_2    b103585242_2.tif
# b100689061  file_1    b100689061_1.tif
# b100757698  file_1    b100757698_1.tif
#             file_2    b100757698_2.tif
# b100311647  file_1    b100311647_1.tif
#             file_2    b100311647_2.tif
# b100525519  file_1    b100525519_1.tif
#             file_2    b100525519_2.tif
# b96726647   file_1     b96726647_1.tif
#             file_2     b96726647_2.tif
# b100755999  file_1    b100755999_1.tif
# b96727974   file_1     b96727974_1.tif
# b103794979  file_1    b103794979_1.tif
# b100532263  file_1    b100532263_1.tif
#             file_2    b100532263_2.tif
# b103522918  file_1    b103522918_1.tif
# b99317400   file_1     b99317400_1.tif
# b103609192  file_1    b103609192_1.tif
#             file_2    b103609192_2.tif
# b100530898  file_1    b100530898_1.tif
# b10052798x  file_1    b10052798x_1.tif
# b103842883  file_1    b103842883_1.tif
# b103584316  file_1    b103584316_1.tif
# b100711510  file_1    b100711510_1.tif
# Length: 154, dtype: object

# %% [markdown]
# We'll have to reset the index in order to get the bib numbers to "fill down" correctly

# %%
df2 = df2.reset_index()
df2.index.name = None
print(df2)
# Out:
#         level_0 level_1                 0
# 0    b100291089  file_1  b100291089_1.tif
# 1    b100291089  file_2  b100291089_2.tif
# 2    b10343608x  file_1  b10343608x_1.tif
# 3     b9675820x  file_1   b9675820x_1.tif
# 4    b103565759  file_1  b103565759_1.tif
# 5    b103565759  file_2  b103565759_2.tif
# 6    b103720285  file_1  b103720285_1.tif
# 7    b103436133  file_1  b103436133_1.tif
# 8    b100710001  file_1  b100710001_1.tif
# 9    b103785012  file_1  b103785012_1.tif
# 10   b103785012  file_2  b103785012_2.tif
# 11   b10065731x  file_1  b10065731x_1.tif
# 12   b103784457  file_1  b103784457_1.tif
# 13   b103784457  file_2  b103784457_2.tif
# 14   b103719593  file_1  b103719593_1.tif
# 15   b100311556  file_1  b100311556_1.tif
# 16   b103836895  file_1  b103836895_1.tif
# 17   b103836895  file_2  b103836895_2.tif
# 18   b100753668  file_1  b100753668_1.tif
# 19   b103722154  file_1  b103722154_1.tif
# 20   b103722154  file_2  b103722154_2.tif
# 21   b103719829  file_1  b103719829_1.tif
# 22   b103503584  file_1  b103503584_1.tif
# 23   b103831137  file_1  b103831137_1.tif
# 24   b103618685  file_1  b103618685_1.tif
# 25   b103618685  file_2  b103618685_2.tif
# 26   b100489308  file_1  b100489308_1.tif
# 27   b103786685  file_1  b103786685_1.tif
# 28   b100756013  file_1  b100756013_1.tif
# 29   b103506421  file_1  b103506421_1.tif
# ..          ...     ...               ...
# 124  b103722683  file_2  b103722683_2.tif
# 125  b103618636  file_1  b103618636_1.tif
# 126  b103618636  file_2  b103618636_2.tif
# 127  b103584225  file_1  b103584225_1.tif
# 128  b100752615  file_1  b100752615_1.tif
# 129  b103585242  file_1  b103585242_1.tif
# 130  b103585242  file_2  b103585242_2.tif
# 131  b100689061  file_1  b100689061_1.tif
# 132  b100757698  file_1  b100757698_1.tif
# 133  b100757698  file_2  b100757698_2.tif
# 134  b100311647  file_1  b100311647_1.tif
# 135  b100311647  file_2  b100311647_2.tif
# 136  b100525519  file_1  b100525519_1.tif
# 137  b100525519  file_2  b100525519_2.tif
# 138   b96726647  file_1   b96726647_1.tif
# 139   b96726647  file_2   b96726647_2.tif
# 140  b100755999  file_1  b100755999_1.tif
# 141   b96727974  file_1   b96727974_1.tif
# 142  b103794979  file_1  b103794979_1.tif
# 143  b100532263  file_1  b100532263_1.tif
# 144  b100532263  file_2  b100532263_2.tif
# 145  b103522918  file_1  b103522918_1.tif
# 146   b99317400  file_1   b99317400_1.tif
# 147  b103609192  file_1  b103609192_1.tif
# 148  b103609192  file_2  b103609192_2.tif
# 149  b100530898  file_1  b100530898_1.tif
# 150  b10052798x  file_1  b10052798x_1.tif
# 151  b103842883  file_1  b103842883_1.tif
# 152  b103584316  file_1  b103584316_1.tif
# 153  b100711510  file_1  b100711510_1.tif
#
# [154 rows x 3 columns]

# %% [markdown]
# Now, we can make a dataframe of all the 'dupe' ARKs. First let's find all the duplicate ARKs, which will let us know these are complex objects.

# %%
df_duplicates = df2.duplicated(subset=['level_0'])
df_duplicates
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20      True
# 21     False
# 22     False
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 124     True
# 125    False
# 126     True
# 127    False
# 128    False
# 129    False
# 130     True
# 131    False
# 132    False
# 133     True
# 134    False
# 135     True
# 136    False
# 137     True
# 138    False
# 139     True
# 140    False
# 141    False
# 142    False
# 143    False
# 144     True
# 145    False
# 146    False
# 147    False
# 148     True
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# Length: 154, dtype: bool

# %% [markdown]
# Now we can get the values of those "True" rows

# %%
arks = df2["level_0"]
dupe_df = df2[arks.isin(arks[arks.duplicated()])]

# %%
dupe_arks = dupe_df["level_0"]
dupe_arks
# Out:
# 0      b100291089
# 1      b100291089
# 4      b103565759
# 5      b103565759
# 9      b103785012
# 10     b103785012
# 12     b103784457
# 13     b103784457
# 16     b103836895
# 17     b103836895
# 19     b103722154
# 20     b103722154
# 24     b103618685
# 25     b103618685
# 29     b103506421
# 30     b103506421
# 38     b103831034
# 39     b103831034
# 43     b100751726
# 44     b100751726
# 46     b103618454
# 47     b103618454
# 51     b103609441
# 52     b103609441
# 53     b100659615
# 54     b100659615
# 55     b103705545
# 56     b103705545
# 58     b100294753
# 59     b100294753
#           ...
# 101    b103785954
# 102    b103785954
# 110    b103504497
# 111    b103504497
# 113    b103833493
# 114    b103833493
# 115    b100532032
# 116    b100532032
# 118     b9672979x
# 119     b9672979x
# 121    b100295915
# 122    b100295915
# 123    b103722683
# 124    b103722683
# 125    b103618636
# 126    b103618636
# 129    b103585242
# 130    b103585242
# 132    b100757698
# 133    b100757698
# 134    b100311647
# 135    b100311647
# 136    b100525519
# 137    b100525519
# 138     b96726647
# 139     b96726647
# 143    b100532263
# 144    b100532263
# 147    b103609192
# 148    b103609192
# Name: level_0, Length: 86, dtype: object

# %%
dupe_arks = dupe_arks.unique()
dupe_arks
# Out:
# array(['b100291089', 'b103565759', 'b103785012', 'b103784457',
#        'b103836895', 'b103722154', 'b103618685', 'b103506421',
#        'b103831034', 'b100751726', 'b103618454', 'b103609441',
#        'b100659615', 'b103705545', 'b100294753', 'b100713671',
#        'b100757054', 'b100531088', 'b103786387', 'b103722634',
#        'b103568414', 'b103705429', 'b100294790', 'b100313723',
#        'b100294935', 'b100310758', 'b103836512', 'b100489114',
#        'b103785954', 'b103504497', 'b103833493', 'b100532032',
#        'b9672979x', 'b100295915', 'b103722683', 'b103618636',
#        'b103585242', 'b100757698', 'b100311647', 'b100525519',
#        'b96726647', 'b100532263', 'b103609192'], dtype=object)

# %% [markdown]
# Now we can make a dataframe of the dupe ARKs

# %%
dupe_df = pd.DataFrame({'level_0':dupe_arks})
dupe_df
# Out:
#        level_0
# 0   b100291089
# 1   b103565759
# 2   b103785012
# 3   b103784457
# 4   b103836895
# 5   b103722154
# 6   b103618685
# 7   b103506421
# 8   b103831034
# 9   b100751726
# 10  b103618454
# 11  b103609441
# 12  b100659615
# 13  b103705545
# 14  b100294753
# 15  b100713671
# 16  b100757054
# 17  b100531088
# 18  b103786387
# 19  b103722634
# 20  b103568414
# 21  b103705429
# 22  b100294790
# 23  b100313723
# 24  b100294935
# 25  b100310758
# 26  b103836512
# 27  b100489114
# 28  b103785954
# 29  b103504497
# 30  b103833493
# 31  b100532032
# 32   b9672979x
# 33  b100295915
# 34  b103722683
# 35  b103618636
# 36  b103585242
# 37  b100757698
# 38  b100311647
# 39  b100525519
# 40   b96726647
# 41  b100532263
# 42  b103609192

# %% [markdown]
# Now we can concatenate the two dataframes

# %%
final_df = pd.concat([df2, dupe_df], sort=True, ignore_index=True)

# %%
final_df
# Out:
#         level_0 level_1                 0
# 0    b100291089  file_1  b100291089_1.tif
# 1    b100291089  file_2  b100291089_2.tif
# 2    b10343608x  file_1  b10343608x_1.tif
# 3     b9675820x  file_1   b9675820x_1.tif
# 4    b103565759  file_1  b103565759_1.tif
# 5    b103565759  file_2  b103565759_2.tif
# 6    b103720285  file_1  b103720285_1.tif
# 7    b103436133  file_1  b103436133_1.tif
# 8    b100710001  file_1  b100710001_1.tif
# 9    b103785012  file_1  b103785012_1.tif
# 10   b103785012  file_2  b103785012_2.tif
# 11   b10065731x  file_1  b10065731x_1.tif
# 12   b103784457  file_1  b103784457_1.tif
# 13   b103784457  file_2  b103784457_2.tif
# 14   b103719593  file_1  b103719593_1.tif
# 15   b100311556  file_1  b100311556_1.tif
# 16   b103836895  file_1  b103836895_1.tif
# 17   b103836895  file_2  b103836895_2.tif
# 18   b100753668  file_1  b100753668_1.tif
# 19   b103722154  file_1  b103722154_1.tif
# 20   b103722154  file_2  b103722154_2.tif
# 21   b103719829  file_1  b103719829_1.tif
# 22   b103503584  file_1  b103503584_1.tif
# 23   b103831137  file_1  b103831137_1.tif
# 24   b103618685  file_1  b103618685_1.tif
# 25   b103618685  file_2  b103618685_2.tif
# 26   b100489308  file_1  b100489308_1.tif
# 27   b103786685  file_1  b103786685_1.tif
# 28   b100756013  file_1  b100756013_1.tif
# 29   b103506421  file_1  b103506421_1.tif
# ..          ...     ...               ...
# 167  b103705545     NaN               NaN
# 168  b100294753     NaN               NaN
# 169  b100713671     NaN               NaN
# 170  b100757054     NaN               NaN
# 171  b100531088     NaN               NaN
# 172  b103786387     NaN               NaN
# 173  b103722634     NaN               NaN
# 174  b103568414     NaN               NaN
# 175  b103705429     NaN               NaN
# 176  b100294790     NaN               NaN
# 177  b100313723     NaN               NaN
# 178  b100294935     NaN               NaN
# 179  b100310758     NaN               NaN
# 180  b103836512     NaN               NaN
# 181  b100489114     NaN               NaN
# 182  b103785954     NaN               NaN
# 183  b103504497     NaN               NaN
# 184  b103833493     NaN               NaN
# 185  b100532032     NaN               NaN
# 186   b9672979x     NaN               NaN
# 187  b100295915     NaN               NaN
# 188  b103722683     NaN               NaN
# 189  b103618636     NaN               NaN
# 190  b103585242     NaN               NaN
# 191  b100757698     NaN               NaN
# 192  b100311647     NaN               NaN
# 193  b100525519     NaN               NaN
# 194   b96726647     NaN               NaN
# 195  b100532263     NaN               NaN
# 196  b103609192     NaN               NaN
#
# [197 rows x 3 columns]

# %% [markdown]
# Finally, we can sort the dataframe so that complex objects are grouped by their empty header row first

# %%
final_df = final_df.sort_values(by=['level_0','level_1'], na_position='first')
final_df
# Out:
#         level_0 level_1                 0
# 154  b100291089     NaN               NaN
# 0    b100291089  file_1  b100291089_1.tif
# 1    b100291089  file_2  b100291089_2.tif
# 168  b100294753     NaN               NaN
# 58   b100294753  file_1  b100294753_1.tif
# 59   b100294753  file_2  b100294753_2.tif
# 176  b100294790     NaN               NaN
# 84   b100294790  file_1  b100294790_1.tif
# 85   b100294790  file_2  b100294790_2.tif
# 178  b100294935     NaN               NaN
# 89   b100294935  file_1  b100294935_1.tif
# 90   b100294935  file_2  b100294935_2.tif
# 187  b100295915     NaN               NaN
# 121  b100295915  file_1  b100295915_1.tif
# 122  b100295915  file_2  b100295915_2.tif
# 179  b100310758     NaN               NaN
# 92   b100310758  file_1  b100310758_1.tif
# 93   b100310758  file_2  b100310758_2.tif
# 104  b100310990  file_1  b100310990_1.tif
# 15   b100311556  file_1  b100311556_1.tif
# 192  b100311647     NaN               NaN
# 134  b100311647  file_1  b100311647_1.tif
# 135  b100311647  file_2  b100311647_2.tif
# 177  b100313723     NaN               NaN
# 86   b100313723  file_1  b100313723_1.tif
# 87   b100313723  file_2  b100313723_2.tif
# 181  b100489114     NaN               NaN
# 98   b100489114  file_1  b100489114_1.tif
# 99   b100489114  file_2  b100489114_2.tif
# 26   b100489308  file_1  b100489308_1.tif
# ..          ...     ...               ...
# 142  b103794979  file_1  b103794979_1.tif
# 162  b103831034     NaN               NaN
# 38   b103831034  file_1  b103831034_1.tif
# 39   b103831034  file_2  b103831034_2.tif
# 23   b103831137  file_1  b103831137_1.tif
# 184  b103833493     NaN               NaN
# 113  b103833493  file_1  b103833493_1.tif
# 114  b103833493  file_2  b103833493_2.tif
# 180  b103836512     NaN               NaN
# 94   b103836512  file_1  b103836512_1.tif
# 95   b103836512  file_2  b103836512_2.tif
# 76   b103836640  file_1  b103836640_1.tif
# 158  b103836895     NaN               NaN
# 16   b103836895  file_1  b103836895_1.tif
# 17   b103836895  file_2  b103836895_2.tif
# 151  b103842883  file_1  b103842883_1.tif
# 70   b103843255  file_1  b103843255_1.tif
# 32   b103926197  file_1  b103926197_1.tif
# 194   b96726647     NaN               NaN
# 138   b96726647  file_1   b96726647_1.tif
# 139   b96726647  file_2   b96726647_2.tif
# 78    b96727561  file_1   b96727561_1.tif
# 141   b96727974  file_1   b96727974_1.tif
# 186   b9672979x     NaN               NaN
# 118   b9672979x  file_1   b9672979x_1.tif
# 119   b9672979x  file_2   b9672979x_2.tif
# 3     b9675820x  file_1   b9675820x_1.tif
# 146   b99317400  file_1   b99317400_1.tif
# 100   b99321488  file_1   b99321488_1.tif
# 57    b99338907  file_1   b99338907_1.tif
#
# [197 rows x 3 columns]

# %%
# Uncomment to print out!
# final_df.to_csv('~/Documents/md_structured.csv')
